# %% [markdown]
# # Abogen on Google Colab
#
# This notebook sets up and runs [Abogen](https://github.com/denizsafak/abogen), an audiobook generator.
#
# ## Step 1: Setup Environment
# Install system dependencies required for audio processing.

# %%
# !nvidia-smi
# !sudo apt-get update && sudo apt-get install -y espeak-ng ffmpeg

# %% [markdown]
# ## Step 2: Install Abogen
# Clone the repository and install Python dependencies.

# %%
# !rm -rf abogen
# !git clone https://github.com/Andy1996247/abogen2.git abogen
# %cd abogen
# %pip install -e .
# %pip install gradio

# %% [markdown]
# ## Step 3: Run Application
# Run the Gradio web interface (headless mode for Colab).

# %%
# Run the custom Gradio wrapper
# !python abogen_gradio.py
